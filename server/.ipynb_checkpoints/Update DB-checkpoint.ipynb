# %%
import pandas as pd
import numpy as np
from neo4j import GraphDatabase

import json
import yapf.yapflib.yapf_api

# %%
dt = pd.read_csv("./relation_new.csv")
data = pd.DataFrame(dt)

# %%
start_node = list(data['source'])
end_node = list(data['target'])
age_group = list(data['age_group'])
onset_date = list(data['onset_date'])
announce_date = list(data['announce_date'])
name = list(data['name'])
rel_id = list(data['relationship'])

# %%
def gen_properties(name, full_name, onset_date, announce_date, age_group):
    p = ''
    p = '{name:"'+name+'", full_name:"'+full_name+'", age_group:'+str(age_group)+', onset_date:date("'+onset_date+'"),announce_date:date("'+announce_date+'")}'
    return p

def gen_query_node(name, full_name, onset_date, announce_date, age_group):
    attr = gen_properties(name, full_name, onset_date, announce_date, age_group)
    query = ("""
    CREATE (n:G{0}{1})
    """).format(age_group, attr)
    return query

# %%
gen_query_node(end_node[0], name[0], onset_date[0], announce_date[0], age_group[0])
# Out:
# '\n    CREATE (n:G3{name:"BN416", full_name:"Trần Văn Dũng", age_group:3, onset_date:date("2020-07-17"),announce_date:date("2020-07-25")})\n    '

# %%
uri = 'bolt://localhost:7687'

g = GraphDatabase.driver(uri, auth=('neo4j', '123'))

# %%
def import_db():
    with g.session() as session:
        for i in range(len(end_node)):
            try:
                session.run(gen_query_node(end_node[i], name[i], onset_date[i], announce_date[i], age_group[i]))
            except:
                pass
import_db()

# %%
rel_type = {'0': "Unknown", '1': "Staff_Patience", '2': "Fellow", '3':"Relatives", '4':"Social"}
def gen_query_edge(src, target, rel_id):
    r_type = rel_type[str(rel_id)]
    query = ("""
    MATCH (s), (t)
    WHERE s.name = "{0}" AND t.name = "{1}"
    CREATE (s)-[r:{2}]->(t)
    """).format(src, target, r_type)
    return query

# %%
def create_relationship(start_node, end_node, rel_id):
    with g.session() as session:
        for s, t, r in zip(start_node, end_node, rel_id):
            if s!='0':
                session.run(gen_query_edge(s, t, r))
create_relationship(start_node, end_node, rel_id)

# %%
merge_relationship(key, target, rel_type)

# %%
g = []
for src in graph.keys():
    if graph[src]!=[]:
        for trg in graph[src]:
            g.append({src:trg})

# %%
h = []
for n in g:
    h.append([list(n.items())[0][0], list(n.items())[0][1]])

# %%
t = pd.DataFrame(h)

# %%
with open('data.csv', 'w+') as f:
    t.to_csv(f)
